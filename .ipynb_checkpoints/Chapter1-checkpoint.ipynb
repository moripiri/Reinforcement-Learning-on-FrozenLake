# %% [markdown]
# ## Chapter 1: Introduction to Reinforcement Learning

# %% [markdown]
# ### 1. What is Reinforcement learning (RL)?
#
# <font size="4">An area of machine learning that aims to learn what to do to: so as to maximize a numerical reward signal! </br>
# It is currently used in many fields, such as game, robotic control, stock trading, etc...</font>
#
# ---

# %% [markdown]
# ### 2. Agents and Environments
#
#
#
# <img src="./Images/agent_environment.png" width="350"/>
#
# <font size="3"> At each timestep $t$ </font>
# * <font size="3"> **Agents**: Receives Reward $R_t$ and Observation $O_t$, executes Action $A_t$ </font>
# * <font size="3"> **Environments**: Receives Action $A_t$, then emits Reward $R_{t+1}$ and Next Observation $O_{t+1}$  </font>
#
# <font size="3">The sequence of observations, actions, rewards are called history.</br>
# </font>
#
# <font size="4"><center>$H_t = O_1, R_1, A_1, ... , A_{t-1}, O_t, R_t$</center></font>
# </br>
# </br>
# <font size="3"> State$(S_t)$: information used to determine what happens next. Both agent and environment have state, and it may not agree with each other.</font>
#
# * <font size="3">**Fully observable environments**: $O_t = S_t$. Agent can know exact state of the environment. It is called **markov decision process (MDP)**</font>
# * <font size="3">**Partially observable environments**: $O_t \neq S_t$. Agent only know partial state of the environment. It is called **partially observable markov decision process (POMDP)**</font>

# %% [markdown]
# <font size="4">Real world problems are more likely to be POMDP, but for easier understanding of RL, we will use MDP that [OpenAI Gym](https://gymnasium.farama.org/) provides.</font>

# %%
import gymnasium as gym
import matplotlib
import IPython
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

print(f"Gym verison: {gym.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
# Out:
# Gym verison: 0.26.3
# Matplotlib version: 3.6.3

# %% [markdown]
# <font size="4"> **[FrozenLake-v1](https://gymnasium.farama.org/environments/toy_text/frozen_lake/)** is an environment that involves crossing a frozen lake from start to goal without falling into any holes by walking over the frozen lake.</br></br>
# The player can move in four directions:
# * <font size="3">**0: Move left**</font>
# * <font size="3">**1: Move down**</font>
# * <font size="3">**2: Move right**</font>
# * <font size="3">**3: Move up**</font>
# </font>
#
# <font size="4">
# and only can get reward at the goal (gift box).</br>
# You can try it by yourself!</font>

# %%
env = gym.make("FrozenLake-v1", render_mode='rgb_array', is_slippery=False)
env.reset()

img = plt.imshow(env.render())
display.display(plt.gcf())
display.clear_output(wait=True)

done = False
while not done:
    _, _, done, _, _ = env.step(int(input()))
    img.set_data(env.render())
    display.display(plt.gcf())
    display.clear_output(wait=True)

env.close()
